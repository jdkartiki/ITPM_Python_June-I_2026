# %% [markdown]
# 🔹 JSON File Handling
#
# JSON = **JavaScript Object Notation**
#
# Features:
#
# * Data stored as **key-value pairs**
# * Lightweight
# * Used in APIs, web apps
#
# * JSON : JavaScript Object Notation
# * structured data format
# * key and value pair
# * easy for machines to parse and generate the output
# * JSON is a lightweight text-based format used to store and exchange data between systems (backend)
#
# ---
#
# Writing JSON
#
# ```python
# import json
#
# data = {"name": "Kartiki", "age": 25}
#
# with open("data.json", "w") as f:
#     json.dump(data, f)
# ```
#
# ---
#
# Reading JSON
#
# ```python
# import json
#
# with open("data.json", "r") as f:
#     data = json.load(f)
#     print(data)
# ```
#
# ---
#
# * JSON vs Python
#
# | JSON       | Python     |
# | ---------- | ---------- |
# | object     | dict       |
# | array      | list       |
# | true/false | True/False |
#
# ---

# %%
# write json file
import json 
data={"name":"Soham","address":"Nanded","age":22}
with open("data.json","w") as f:
    json.dump(data,f)

# %%
# read file 
import json 
with open("data.json","r") as f:
    print(json.load(f))
# Out:
# {'name': 'Soham', 'address': 'Nanded', 'age': 22}

# %%
# append == Directly not done : read + write 

# read file 
import json 
with open("data.json","r") as f:
    print(json.load(f))

data["city"]="Katraj"
with open("data.json","w") as f:
    json.dump(data,f)
     
with open("data.json","r") as f:
    print(json.load(f))
# Out:
# {'name': 'Soham', 'address': 'Nanded', 'age': 22}
# {'name': 'Soham', 'address': 'Nanded', 'age': 22, 'city': 'Katraj'}

# %%
# pretty print
import json 
data={"name":"Soham","address":"Nanded","age":22}
with open("xyz.json","w") as f:
    json.dump(data,f,indent=4)

# %%
# read +write : r+ : append + write

import json
with open("demo.json", "r+") as f:
    data = json.load(f)
    data["new"] = 123
    f.seek(0)
    json.dump(data, f)

# %%
# Write + read = w+

import json
with open("demo.json", "w+") as f:
    json.dump({"age":10}, f)
    f.seek(0)
    print(json.load(f))
# Out:
# {'age': 10}

# %%
# convert json to string -- interview 

import json
data = {"a":1}
print(json.dumps(data))
# Out:
# {"a": 1}

# %%
# string to json

import json
s = '{"a":1}'
print(json.loads(s))
# Out:
# {'a': 1}

# %%
# nested json access 

import json
data = {"user": {"name": "Amit"}}
print(data["user"]["name"])
# Out:
# Amit

# %%
import json

data = {
    "users": [
        {"name": "Amit"},
        {"name": "Raj"}
    ]
}

print(data["users"][0]["name"])  # Amit
print(data["users"][1]["name"])  # Raj
# Out:
# Amit
# Raj

# %%
import json

data = {
    "users": [
        {"name": "Amit"},
        {"name": "Raj"},
        {"name": "Neha"}
    ]
}

for user in data["users"]:
    print(user["name"])
# Out:
# Amit
# Raj
# Neha
