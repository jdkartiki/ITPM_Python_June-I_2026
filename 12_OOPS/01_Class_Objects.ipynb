# %% [markdown]
# 1. OOP (Object-Oriented Programming)
#
# Definition:
# OOP is a programming approach where we organize code using **classes and objects**.
#
# Purpose of OOP:
# * Makes code **easy to understand**
# * Helps in **code reusability**
# * Improves **security (data hiding)**
# * Makes programs **modular and structured**
# ---
#
# 2. Class
#
# Definition:
# A **class** is a blueprint or template used to create objects.
# It defines properties (variables) and methods (functions).
#
# Example:
# * class Student:
#     name = "Kartiki"
#
# ---
#
# 3. Object
#
# Definition:
# An **object** is an instance of a class.
# It represents a real-world entity and can use the properties and methods of the class.
#
# Example:
# * s1 = Student()
# print(s1.name)
# * s2=Student()
# print(s2.name)
# ---
#
# 4. Constructor
#
# Definition:
# A **constructor** is a special method in a class that is automatically called when an object is created.
#
# * In Python, it is written as `__init__()`
#
# Example:
#
# * class Student:
#     def __init__(self, name):
#         self.name = name
#
# s1 = Student("Kartiki")
# print(s1.name)
#
#
# Output:
#
# ```
# Kartiki
# ```
#
# ---
#
# Short Summary (for revision):
#
# 1. **Class** → Blueprint
# 2. **Object** → Instance of class
# 3. **OOP** → Programming using classes & objects
# 4. **Constructor** → Auto-called method when object is created

# %%
class Student:
    def show(self):
        print("This is a Student Class ")


#object
s1=Student()
s1.show()

s2=Student()
s2.show()
# Out:
# This is a Student Class
# This is a Student Class

# %%
class Student:
    rollno=1
    name="Ram"


s1=Student()
print("Roll no is :: ",s1.rollno)
print("Name  is :: ",s1.name)
# Out:
# Roll no is ::  1
# Name  is ::  Ram

# %%
class Employee:
    id=1
    name="ram"
    designation="developer"
    dept="cs"


e=Employee()
print("Emp ID is :: ",e.id)
print("Emp Name is :: ",e.name)
print("Emp Designation is :: ",e.designation)
print("Emp Department is :: ",e.dept)

e1=Employee()
print("Emp ID is :: ",e1.id)
print("Emp Name is :: ",e1.name)
print("Emp Designation is :: ",e1.designation)
print("Emp Department is :: ",e1.dept)
# Out:
# Emp ID is ::  1
# Emp Name is ::  ram
# Emp Designation is ::  developer
# Emp Department is ::  cs
# Emp ID is ::  1
# Emp Name is ::  ram
# Emp Designation is ::  developer
# Emp Department is ::  cs

# %%
class Employee:
    def accept(self,name,salary):
        self.name=name
        self.salary=salary 

    def display(self):
        print("Name is :: ",self.name)
        print("Salary is :: ",self.salary)


e1=Employee()
e2=Employee()


e1.accept("Ram",50000)
e2.accept("Raj",30000)

e1.display()
e2.display()
# Out:
# Name is ::  Ram
# Salary is ::  50000
# Name is ::  Raj
# Salary is ::  30000

# %%
class Employee:
    def __init__(self,name,sal):
        self.name=name
        self.sal=sal

    def display(self):
        print("Name is :: ",self.name)
        print("Salary is :: ",self.sal)

e1=Employee("Ram",50000)
e2=Employee("Raj",30000)

e1.display()
e2.display()
# Out:
# Name is ::  Ram
# Salary is ::  50000
# Name is ::  Raj
# Salary is ::  30000

# %%
class Bank:
    def __init__(self,balance):
        self.balance=balance

    def display_bal(self):
        print("Current Balance is :: ",self.balance)


b=Bank(50000)
b.display_bal()
# Out:
# Current Balance is ::  50000

# %%
#update value in object 

class Student:
    def __init__(self,name):
        self.name=name

s=Student("Amit")
print(s.name)

s.name="Ram"
print(s.name)
# Out:
# Amit
# Ram

# %%
class EvenOdd:
    def check(self,num):
        if num%2==0:
            print("Even ")
        else:
            print("Odd")

n=EvenOdd()
n.check(8)
# Out:
# Even

# %%
class Product:
    def __init__(self,name,price):
        self.name=name
        self.price=price


p1=Product("Laptop",50000)
print(p1.name,p1.price)

p2=Product("Headphones",500)
print(p2.name,p2.price)
# Out:
# Laptop 50000
# Headphones 500

# %%
# create a class name Courses

# using constructor initialize courseid, coursename, duration 
# create 3 objects and print it
