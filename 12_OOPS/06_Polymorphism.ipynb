# %%
## 🔷 Polymorphism in Python

**Polymorphism** means *“many forms”*. In Python, it allows the same function or method name to behave differently depending on the object or data type.

👉 In simple words:
**One interface → Multiple implementations**

---

# 🔹 Types of Polymorphism in Python

## 1. Method Overriding (Runtime Polymorphism)

When a **child class provides a different implementation** of a method that already exists in the parent class.

### ✅ Example:

```python
class Animal:
    def speak(self):
        print("Animal makes sound")

class Dog(Animal):
    def speak(self):
        print("Dog barks")

class Cat(Animal):
    def speak(self):
        print("Cat meows")


# Usage
a = Animal()
d = Dog()
c = Cat()

a.speak()
d.speak()
c.speak()
```

### 🔍 Output:

```
Animal makes sound
Dog barks
Cat meows
```

👉 Same method `speak()` behaves differently.

---

## 2. Method Overloading (Compile-time style)

Python does **not support true method overloading**, but we can achieve it using:

* Default arguments
* `*args`

### ✅ Example using default arguments:

```python
class Math:
    def add(self, a, b, c=0):
        return a + b + c

m = Math()

print(m.add(2, 3))       # 5
print(m.add(2, 3, 4))    # 9
```

👉 Same method works with different number of arguments.

---

## 3. Operator Overloading

Python allows operators (`+`, `-`, `*`) to work differently for objects using **magic methods**.

### ✅ Example:

```python
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def display(self):
        print(self.x, self.y)


p1 = Point(2, 3)
p2 = Point(4, 5)

p3 = p1 + p2
p3.display()
```

### 🔍 Output:

```
6 8
```

👉 `+` operator works for custom objects.

---

## 4. Duck Typing (Dynamic Polymorphism)

Python focuses on **behavior, not type**.

👉 “If it looks like a duck and behaves like a duck, it is a duck.”

### ✅ Example:

```python
class Bird:
    def fly(self):
        print("Bird can fly")

class Airplane:
    def fly(self):
        print("Airplane flies")

def make_fly(obj):
    obj.fly()

b = Bird()
a = Airplane()

make_fly(b)
make_fly(a)
```

### 🔍 Output:

```
Bird can fly
Airplane flies
```

👉 No inheritance required — just same method name.

---

# 🔥 Summary Table

| Type                 | Description                                    |
| -------------------- | ---------------------------------------------- |
| Method Overriding    | Same method, different behavior in child class |
| Method Overloading   | Same method, different parameters              |
| Operator Overloading | Operators behave differently                   |
| Duck Typing          | Object behavior matters, not type              |

---

# 🚀 Real-Life Example

Think of a **remote control**:

* Same button → different TVs react differently
  👉 That’s polymorphism!

---

If you want, I can give:

* 💯 Interview questions on polymorphism
* 🧠 Tricky coding problems
* 📊 Diagrams for better understanding

Just tell me 👍

# %% [markdown]
#  🔷 Polymorphism in Python
#
# **Polymorphism** means *“many forms”*. In Python, it allows the same function or method name to behave differently depending on the object or data type.
#
# 👉 In simple words:
# **One interface → Multiple implementations**
#
# ---
#
#  🔹 Types of Polymorphism in Python
#
#  1. Method Overriding (Runtime Polymorphism)
#
# When a **child class provides a different implementation** of a method that already exists in the parent class.
#
#  ✅ Example:
#
# ```python
# class Animal:
#     def speak(self):
#         print("Animal makes sound")
#
# class Dog(Animal):
#     def speak(self):
#         print("Dog barks")
#
# class Cat(Animal):
#     def speak(self):
#         print("Cat meows")
#
#
# # Usage
# a = Animal()
# d = Dog()
# c = Cat()
#
# a.speak()
# d.speak()
# c.speak()
# ```
#
#  🔍 Output:
#
# ```
# Animal makes sound
# Dog barks
# Cat meows
# ```
#
# 👉 Same method `speak()` behaves differently.
#
# ---
#
#  2. Method Overloading (Compile-time style)
#
# Python does **not support true method overloading**, but we can achieve it using:
#
# * Default arguments
# * `*args`
#
#  ✅ Example using default arguments:
#
# ```python
# class Math:
#     def add(self, a, b, c=0):
#         return a + b + c
#
# m = Math()
#
# print(m.add(2, 3))       # 5
# print(m.add(2, 3, 4))    # 9
# ```
#
# 👉 Same method works with different number of arguments.
#
# ---
#
#  3. Operator Overloading
#
# Python allows operators (`+`, `-`, `*`) to work differently for objects using **magic methods**.
#
#  ✅ Example:
#
# ```python
# class Point:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
#     def __add__(self, other):
#         return Point(self.x + other.x, self.y + other.y)
#
#     def display(self):
#         print(self.x, self.y)
#
#
# p1 = Point(2, 3)
# p2 = Point(4, 5)
#
# p3 = p1 + p2
# p3.display()
# ```
#
#  🔍 Output:
#
# ```
# 6 8
# ```
#
# 👉 `+` operator works for custom objects.
#
# ---
#
#  4. Duck Typing (Dynamic Polymorphism)
#
# Python focuses on **behavior, not type**.
#
# 👉 “If it looks like a duck and behaves like a duck, it is a duck.”
#
#  ✅ Example:
#
# ```python
# class Bird:
#     def fly(self):
#         print("Bird can fly")
#
# class Airplane:
#     def fly(self):
#         print("Airplane flies")
#
# def make_fly(obj):
#     obj.fly()
#
# b = Bird()
# a = Airplane()
#
# make_fly(b)
# make_fly(a)
# ```
#
# 🔍 Output:
#
# ```
# Bird can fly
# Airplane flies
# ```
#
# 👉 No inheritance required — just same method name.
#
# ---
#
#  🔥 Summary Table
#
# | Type                 | Description                                    |
# | -------------------- | ---------------------------------------------- |
# | Method Overriding    | Same method, different behavior in child class |
# | Method Overloading   | Same method, different parameters              |
# | Operator Overloading | Operators behave differently                   |
# | Duck Typing          | Object behavior matters, not type              |
#
# ---
#
# 🚀 Real-Life Example
#
# Think of a **remote control**:
#
# * Same button → different TVs react differently
#   1.👉 That’s polymorphism!

# %% [markdown]
# Operator Overloading
# * Python __add__() function is one of the magic methods in Python that returns a new object(third) i.e. the addition of the other two objects. It implements the addition operator "+" in Python.
#
# Note
# *  "+" any number of operands
# * __add__ :compulsary 2 operands
#
# Operators behave differently

# %%
# operator Overloading
class Number:
    def __init__(self,val):
        self.val=val

    def __add__(self, other):
        return self.val+other.val
    

n1=Number(5)
n2=Number(10)
print(n1+n2)
# Out:
# 15

# %%
class Person:
    def __init__(self,age):
        self.age=age
     
    def __gt__(self, other):
        return self.age>other.age
    

p1=Person(25)
p2=Person(20)
print(p1>p2)
print(p1<p2)
# Out:
# True
# False

# %%
class Multiply:
    def __init__(self,num):
        self.num=num

    def __mul__(self, other):
        return self.num*other.num
    

m1=Multiply(10)
m2=Multiply(20)
print(m1*m2)
# Out:
# 200

# %%
class Student:
    def __init__(self,name):
        self.name=name

    def __str__(self):
        return f"Student name is :: {self.name}"


s=Student("Aryan")
print(s)
# Out:
# Student name is :: Aryan

# %% [markdown]
# Method Overlaoding : Same Method name but different parameter
# * Same method, different parameters
# * Uses Default Argument to achieve it

# %%
class Demo:
    def add(self,a,b=0):
        return a+b
    
d=Demo()
print(d.add(10,40))
print(d.add(30))
# Out:
# 50
# 30

# %%
class Demo:
    def add(self,*nums):
        return sum(nums)
    
d=Demo()
print(d.add(1,2,3,4))
print(d.add(10,20,30))
print(d.add(10,20,10,10,10,10,10,10,10))
# Out:
# 10
# 60
# 100

# %%
class Demo:
    def display(self,a=None,b=None):
        if b:
            print(a,b)
        else:
            print(a)

d=Demo()
d.display("Hello")
d.display("Hello"," World")
# Out:
# Hello
# Hello  World

# %%
class Area:
    def calculate(self,a,b=None):
        if b:
            return a*b
        return a*a
    
ar=Area()
print(ar.calculate(4)) #square
print(ar.calculate(4,5)) #rectangle
# Out:
# 16
# 20

# %%
class Maths:
    def multiply(self,a,b=1,c=1):
        return a*b*c
    

m=Maths()
print(m.multiply(2))
print(m.multiply(3,4))
print(m.multiply(5,2,3))
# Out:
# 2
# 12
# 30

# %% [markdown]
#  Method Overiding
# * Same method, different behavior in child class
# * require inheritance

# %%
class Payment:
    def pay(self,amount):
        print("Processsing the PAyment !!!")

class CreditCard(Payment):
    def pay(self, amount):
       print(f"Paid Rs. {amount} using Credit Card")
    
class UPI(Payment):
    def pay(self, amount):
       print(f"Paid Rs. {amount} using UPI")

class Cash(Payment):
    def pay(self, amount):
       print(f"Paid Rs. {amount} using Cash")

p1=CreditCard()
p2=UPI()
p3=Cash()

p1.pay(20000)
p2.pay(40000)
p3.pay(10000)
# Out:
# Paid Rs. 20000 using Credit Card
# Paid Rs. 40000 using UPI
# Paid Rs. 10000 using Cash

# %%
class Ride:
    def calculate_fare(self,discount):
        print("Calculating Fare.....")

class BikeRide(Ride):
        def calculate_fare(self,distance):
            print(f"Bike Fare :: Rs. {distance*5}")

class CarRide(Ride):
        def calculate_fare(self,distance):
            print(f"Car Fare :: Rs. {distance*15}")

r1=BikeRide()
r2=CarRide()

r1.calculate_fare(10)
r2.calculate_fare(5)
# Out:
# Bike Fare :: Rs. 50
# Car Fare :: Rs. 75

# %%
class Tax:
    def calculate_tax(self,amount):
        return amount*0.1
    
class IndiaTax(Tax):
    def calculate_tax(self,amount):
        return amount*0.18
    
class USATax(Tax):
    def calculate_tax(self,amount):
        return amount*0.07
    
class UKTax(Tax):
    def calculate_tax(self,amount):
        return amount*0.20
    

taxes=[IndiaTax(),USATax(),UKTax()]

for t in taxes:
    print(t.calculate_tax(20000))
# Out:
# 3600.0
# 1400.0000000000002
# 4000.0

# %%
class Order:
    def calculate_total(self, amount):
        return amount

    def display(self, amount):
        print(f"Total Amount: ₹{self.calculate_total(amount)}")


class DineIn(Order):
    def calculate_total(self, amount):
        return amount + 50   # service charge

    def display(self, amount):
        print(f"Dine-In Order → Base: ₹{amount}, Service Charge: ₹50, Total: ₹{self.calculate_total(amount)}")


class TakeAway(Order):
    def calculate_total(self, amount):
        return amount + 20   # packaging charge

    def display(self, amount):
        print(f"TakeAway Order → Base: ₹{amount}, Packaging Charge: ₹20, Total: ₹{self.calculate_total(amount)}")


class Delivery(Order):
    def calculate_total(self, amount):
        return amount + 100  # delivery charge

    def display(self, amount):
        print(f"Delivery Order → Base: ₹{amount}, Delivery Charge: ₹100, Total: ₹{self.calculate_total(amount)}")


# Usage
orders = [DineIn(), TakeAway(), Delivery()]

for order in orders:
    order.display(500)
# Out:
# Dine-In Order → Base: ₹500, Service Charge: ₹50, Total: ₹550
# TakeAway Order → Base: ₹500, Packaging Charge: ₹20, Total: ₹520
# Delivery Order → Base: ₹500, Delivery Charge: ₹100, Total: ₹600

# %%
class Loan:
    def calculate_interest(self, amount):
        return amount * 0.05

    def display(self, amount):
        print(f"Loan Interest: ₹{self.calculate_interest(amount)}")


class HomeLoan(Loan):
    def calculate_interest(self, amount):
        return amount * 0.07

    def display(self, amount):
        print(f"🏠 Home Loan → Amount: ₹{amount}, Interest: 7%, Total Interest: ₹{self.calculate_interest(amount)}")


class CarLoan(Loan):
    def calculate_interest(self, amount):
        return amount * 0.09

    def display(self, amount):
        print(f"🚗 Car Loan → Amount: ₹{amount}, Interest: 9%, Total Interest: ₹{self.calculate_interest(amount)}")


class PersonalLoan(Loan):
    def calculate_interest(self, amount):
        return amount * 0.12

    def display(self, amount):
        print(f"💳 Personal Loan → Amount: ₹{amount}, Interest: 12%, Total Interest: ₹{self.calculate_interest(amount)}")


# Usage
loans = [HomeLoan(), CarLoan(), PersonalLoan()]

for loan in loans:
    loan.display(100000)
# Out:
# 🏠 Home Loan → Amount: ₹100000, Interest: 7%, Total Interest: ₹7000.000000000001
# 🚗 Car Loan → Amount: ₹100000, Interest: 9%, Total Interest: ₹9000.0
# 💳 Personal Loan → Amount: ₹100000, Interest: 12%, Total Interest: ₹12000.0

# %%
class Export:
    def export(self, data):
        print("Exporting data")


class PDFExport(Export):
    def export(self, data):
        print(f"📄 Exporting '{data}' as PDF file")


class ExcelExport(Export):
    def export(self, data):
        print(f"📊 Exporting '{data}' as Excel sheet")


class CSVExport(Export):
    def export(self, data):
        print(f"🧾 Exporting '{data}' as CSV file")


# Usage
exports = [PDFExport(), ExcelExport(), CSVExport()]

for e in exports:
    e.export("Sales Report 2026")
# Out:
# 📄 Exporting 'Sales Report 2026' as PDF file
# 📊 Exporting 'Sales Report 2026' as Excel sheet
# 🧾 Exporting 'Sales Report 2026' as CSV file

# %% [markdown]
# ##### Explain Compile-time Polymorphism and Run-time Polymorphism with Examples
#
# ---
#
# ##### 1. Compile-time Polymorphism (Static Polymorphism)
#
# ##### Definition
#
# Compile-time polymorphism is the type of polymorphism in which the method to be executed is determined **during compilation**.
#
# In Python, true compile-time polymorphism is **not supported** because Python is a dynamically typed language. However, it can be **simulated using default arguments** (or variable-length arguments).
#
# ##### Advantages
#
# - Faster execution.
# - Improves code readability.
# - Allows the same method to work with different numbers of arguments.
#
# ##### Example (Method Overloading using Default Arguments)
#
# ```python
# class Calculator:
#
#     def add(self, a, b, c=0):
#         print("Addition =", a + b + c)
#
# c = Calculator()
#
# c.add(10, 20)        # Two arguments
# c.add(10, 20, 30)    # Three arguments
# ```
#
# ##### Output
#
# ```text
# Addition = 30
# Addition = 60
# ```
#
# ##### Explanation
#
# - The same method `add()` performs different operations based on the number of arguments passed.
# - This is known as **method overloading**, which represents **compile-time polymorphism** in Python.
#
# ---
#
# ##### 2. Run-time Polymorphism (Dynamic Polymorphism)
#
# ###### Definition
#
# Run-time polymorphism is the type of polymorphism in which the method to be executed is decided **while the program is running**.
#
# In Python, this is achieved using **Method Overriding**.
#
# ##### Advantages
#
# - Supports flexibility.
# - Allows child classes to provide their own implementation.
# - Improves code reusability.
#
# ##### Example (Method Overriding)
#
# ```python
# class Animal:
#
#     def sound(self):
#         print("Animal makes a sound")
#
# class Dog(Animal):
#
#     def sound(self):
#         print("Dog barks")
#
# obj = Dog()
# obj.sound()
# ```
#
# ##### Output
#
# ```text
# Dog barks
# ```
#
# ##### Explanation
#
# - The parent class `Animal` has a `sound()` method.
# - The child class `Dog` overrides the same method.
# - When the object of `Dog` calls `sound()`, Python executes the child class method.
# - This decision is made **at runtime**, so it is called **Run-time Polymorphism**.
#
# ---
#
# ##### Difference Between Compile-time and Run-time Polymorphism
#
# ##### Difference Between Compile-time Polymorphism and Run-time Polymorphism
#
# ### 1. Decision Time
# - **Compile-time Polymorphism:** The method to be executed is decided during **compilation**.
# - **Run-time Polymorphism:** The method to be executed is decided during **program execution (runtime)**.
#
# ---
#
# ### 2. Technique Used
# - **Compile-time Polymorphism:** Achieved using **Method Overloading** (simulated using default arguments in Python).
# - **Run-time Polymorphism:** Achieved using **Method Overriding**.
#
# ---
#
# ### 3. Speed
# - **Compile-time Polymorphism:** Faster because the method is selected before execution.
# - **Run-time Polymorphism:** Slightly slower because the method is selected while the program is running.
#
# ---
#
# ### 4. Method Behavior
# - **Compile-time Polymorphism:** The same method performs different tasks based on the **number or type of arguments**.
# - **Run-time Polymorphism:** The **child class provides its own implementation** of the parent class method.
#
# ---
#
# ### 5. Binding
# - **Compile-time Polymorphism:** Uses **Early Binding (Static Binding)**.
# - **Run-time Polymorphism:** Uses **Late Binding (Dynamic Binding)**.
#
# ---
#
# ### 6. Python Support
# - **Compile-time Polymorphism:** Python does not support true compile-time polymorphism, but it can be simulated using **default arguments**.
# - **Run-time Polymorphism:** Fully supported in Python through **Method Overriding**.
#
# ---
#
# ### 7. Example
# - **Compile-time Polymorphism:** Method Overloading using default arguments.
#
# ```python
# class Calculator:
#
#     def add(self, a, b, c=0):
#         print(a + b + c)
#
# c = Calculator()
# c.add(10, 20)
# c.add(10, 20, 30)
# ```
#
# - **Run-time Polymorphism:** Method Overriding.
#
# ```python
# class Animal:
#
#     def sound(self):
#         print("Animal makes sound")
#
# class Dog(Animal):
#
#     def sound(self):
#         print("Dog barks")
#
# d = Dog()
# d.sound()
# ```
# ---
#
# ##### Exam Tip (2 Marks Answer)
#
# #####  Compile-time Polymorphism
#
# Compile-time polymorphism is achieved when the method to be executed is decided during compilation. In Python, it is simulated using **method overloading with default arguments**.
#
# ##### Example
#
# ```python
# class Demo:
#
#     def add(self, a, b, c=0):
#         print(a + b + c)
#
# d = Demo()
#
# d.add(5, 10)
# d.add(5, 10, 15)
# ```
#
# ---
#
# ##### Run-time Polymorphism
#
# Run-time polymorphism is achieved through **method overriding**, where the child class provides its own implementation of the parent class method. The method is selected during program execution.
#
# ##### Example
#
# ```python
# class Bird:
#
#     def fly(self):
#         print("Bird flies")
#
# class Sparrow(Bird):
#
#     def fly(self):
#         print("Sparrow flies")
#
# b = Sparrow()
# b.fly()
# ```
#
# ---
#
# ##### Key Points
#
# ##### Compile-time Polymorphism
# - Also called **Static Polymorphism**.
# - Achieved using **Method Overloading** (default arguments in Python).
# - Method selection occurs during compilation.
# - Faster execution.
#
# ###### Run-time Polymorphism
# - Also called **Dynamic Polymorphism**.
# - Achieved using **Method Overriding**.
# - Method selection occurs during execution.
# - Provides flexibility and extensibility.

# %% [markdown]
# ### =====================================================================

# %% [markdown]
#  🦆 Duck Typing (in detail)
#
# **Duck typing** is a concept in dynamic programming languages (like Python) where the **type or class of an object is less important than the methods or behaviors it defines**.
#
# The name comes from the famous phrase:
#
# > *“If it walks like a duck and quacks like a duck, then it must be a duck.”*
#
# In programming terms:
#
# * You don’t check an object’s type explicitly.
# * You just **use the object**, assuming it has the required methods/attributes.
# * If it behaves correctly → it works.
# * If not → you get a runtime error.
#
# ---
#
#  🔍 Key Characteristics
#
# * No need for inheritance or interfaces.
# * Focus on **behavior, not type**.
# * Common in dynamically typed languages like Python.
# * Promotes flexibility and polymorphism.
#
# ---
#
#  Simple Example
#
# ```python
# class Duck:
#     def speak(self):
#         print("Quack!")
#
# class Dog:
#     def speak(self):
#         print("Bark!")
#
# def make_sound(animal):
#     animal.speak()
#
# make_sound(Duck())
# make_sound(Dog())
# ```
#
# 👉 Both objects work because they have a `speak()` method — **not because they share a parent class**.

# %%
# 1. Basic Method Sharing

class Cat:
    def sound(self):
        print("Meow")

class Cow:
    def sound(self):
        print("Moo")

def animal_sound(animal):
    animal.sound()

animal_sound(Cat())
animal_sound(Cow())
# Out:
# Meow
# Moo

# %%
# 2. File-like Objects

class File:
    def read(self):
        return "Reading file"

class Network:
    def read(self):
        return "Reading from network"

def read_data(source):
    print(source.read())

read_data(File())
read_data(Network())
# Out:
# Reading file
# Reading from network

# %%
# 3. Different Classes, Same Method Name

class Car:
    def move(self):
        print("Car drives")

class Bird:
    def move(self):
        print("Bird flies")

def start(obj):
    obj.move()

start(Car())
start(Bird())
# Out:
# Car drives
# Bird flies

# %%
# 4. Using Built-in Types

def get_length(item):
    return len(item)

print(get_length("Hello"))
print(get_length([1, 2, 3]))
# Out:
# 5
# 3

# %%
# 5. Operator Duck Typing

def add(a, b):
    return a + b

print(add(10, 20))
print(add("Hello ", "World"))
# Out:
# 30
# Hello World

# %%
# 6. Iterable Duck Typing

def print_items(items):
    for i in items:
        print(i)

print_items([1, 2, 3])
print_items((4, 5, 6))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# 7. Context Manager Style
class Demo:
    def __enter__(self):
        print("Enter")
        return self

    def __exit__(self, exc_type, exc_val, exc_tb):
        print("Exit")

def use(obj):
    with obj:
        print("Inside block")

use(Demo())
# Out:
# Enter
# Inside block
# Exit

# %%
# 8. Custom Object with Same Interface

class Email:
    def send(self):
        print("Sending Email")

class SMS:
    def send(self):
        print("Sending SMS")

def notify(service):
    service.send()

notify(Email())
notify(SMS())
# Out:
# Sending Email
# Sending SMS

# %%
# 9. Multiple Behaviors

class Pen:
    def write(self):
        print("Writing with pen")

class Keyboard:
    def write(self):
        print("Typing on keyboard")

def write_something(tool):
    tool.write()

write_something(Pen())
write_something(Keyboard())
# Out:
# Writing with pen
# Typing on keyboard

# %%
# 10. Mixed Objects in List

class A:
    def show(self):
        print("Class A")

class B:
    def show(self):
        print("Class B")

objects = [A(), B()]

for obj in objects:
    obj.show()
# Out:
# Class A
# Class B

# %%
# Speaker / Phone (Play Sound)

# **Real life:** Anything that can play music works.
class Speaker:
    def play(self):
        print("Playing on Speaker")

class Phone:
    def play(self):
        print("Playing on Phone")

def start_music(device):
    device.play()

start_music(Speaker())
start_music(Phone())
# Out:
# Playing on Speaker
# Playing on Phone

# %%
# Teacher / YouTube (Teach)
# **Real life:** Learning from teacher or online.

class Teacher:
    def teach(self):
        print("Teaching in classroom")

class YouTube:
    def teach(self):
        print("Teaching online")

def learn(source):
    source.teach()

learn(Teacher())
learn(YouTube())
# Out:
# Teaching in classroom
# Teaching online

# %%
# Swiggy / Zomato (Deliver Food)
# **Real life:** Any delivery app works.

class Swiggy:
    def deliver(self):
        print("Food delivered by Swiggy")

class Zomato:
    def deliver(self):
        print("Food delivered by Zomato")

def order(app):
    app.deliver()

order(Swiggy())
order(Zomato())
# Out:
# Food delivered by Swiggy
# Food delivered by Zomato

# %%
# Robot / Human (Clean Room)
# **Real life:** Anyone who can clean works.

class Robot:
    def clean(self):
        print("Robot cleaning")

class Human:
    def clean(self):
        print("Human cleaning")

def clean_room(helper):
    helper.clean()

clean_room(Robot())
clean_room(Human())
# Out:
# Robot cleaning
# Human cleaning
