# %%
# # OOPS -- Object Oriented Programming 

# 1. Class and object
# 2. Constructor

#         4 Pillars OOPS :  
# I. Inheritance 
# II. Polymorphism
# III. Abstraction
# IV. Encapsulation

# %%
# Inheritance : Acquiring the property from parent class to child class 

# Parent : Base class 
# Child : Derived class 

# Types :
# 1. Single : 1 parent - 1 child 
# 2. Multiple : many parent -- 1 Child
# 3. Multilevel : one parent -- multiple child 
# 4. Hierarchical : grandparent - parent- child - grandchild --- 
# 5. Hybrid : mix

# %%
# Single Inheirtance 

#parent
class Employee:
    def show(self):
        print("Employee Details ")

#child
# childclass(parentclass)
class Developer(Employee):
    def code(self):
        print("Developer is writing the code !!! ")


d=Developer()
d.code()
d.show()
# Out:
# Developer is writing the code !!!
# Employee Details

# %%
class Employee:
    def get_Emp(self):
        self.name=input("Enter Employee Name :: ")

class Developer(Employee):
    def get_Dev(self):
        self.language=input("Enter Developer's Language :: ")
        print(self.name," codes in ",self.language)


d=Developer()
d.get_Emp()
d.get_Dev()
# Out:
# Ram  codes in  Python

# %%
class Person:
    def get_name(self):
        self.name=input("Enter Name :: ")

class Student(Person):
    def get_student(self):
        self.marks=int(input("Enter MArks :: "))
        print(self.name, " has scored ",self.marks)

s1=Student()
s1.get_name()
s1.get_student()

s2=Student()
s2.get_name()
s2.get_student()
# Out:
# Ram  has scored  99
# Raj  has scored  88

# %%
class Vehicle:
    def get_details(self):
        self.brand=input("Enter Brand :: ")

class Car(Vehicle):
    def car_details(self):
        self.price=int(input("Enter Price :: "))
        print(self.brand, " costs for ",self.price)


c1=Car()
c1.get_details()
c1.car_details()

c2=Car()
c2.get_details()
c2.car_details()
# Out:
# Tata Punch  costs for  600000
# BMW  costs for  90000000

# %%
class Bank:
    def get_details(self):
        self.bankname=input("Enter Bank Name :: ")

class Account(Bank):
    def get_account(self):
        self.balance=int(input("Enter Balance :: "))
        print(self.bankname, " Bank has balance of Rs. ",self.balance)

a=Account()
a.get_details()
a.get_account()
# Out:
# SBI  Bank has balance of Rs.  20000

# %%
# Multiple Inheritance 

class Father:
    def fatherskill(self):
        print("He Drives So Well ")

class Mother:
    def motherskill(self):
        print("She Cooks So Well ")

class Child(Father,Mother):
    def childskill(self):
        print("Child Can Study ")

obj=Child()
obj.fatherskill()
obj.motherskill()
obj.childskill()
# Out:
# He Drives So Well
# She Cooks So Well
# Child Can Study

# %%
class Teacher:
    def t(self):
        self.subject=input("ENter Subject :: ")

class Writer:
    def w(self):
        self.book=input("Enter Book Name :: ")

class Student(Teacher,Writer):
    def show(self):
        print(self.subject ,"is taught from a book  ",self.book)

s=Student()
s.t()
s.w()
s.show()
# Out:
# PYTHON is taught from a book   LEARN PYTHON EASILY!

# %%
class Camera:
    def cam(self):
        self.mp=input("Enter MP :: ")

class Brand:
    def ph(self):
        self.brand=input("Enter Brand :: ")

class SmartPhone(Camera,Brand):
    def disp(self):
        print("SmartPhone has camera of ",self.mp," and it is of ",self.brand," brand")


s=SmartPhone()
s.cam()
s.ph()
s.disp()
# Out:
# SmartPhone has camera of  120 px  and it is of  Xiomi  brand

# %%
class Song:
    def s(self):
        self.song=input("Enter SOng Name :: ")

class Dancer:
    def d(self):
        self.style=input("Enter Style Of Dance :: ")

class Performer(Song,Dancer):
    def show(self):
        print("Performer is performing on ",self.song, " with dance style ",self.style)

p=Performer()
p.s()
p.d()
p.show()
# Out:
# Performer is performing on  Ganesh Vandana  with dance style  Classical

# %%
# multiple 
class Brand:
    def b(self):
        self.brand=input("Enter Brand NAme :: ")

class RAM:
    def r(self):
        self.ram=input("Enter RAM ")

class GamingLaptop(Brand,RAM):
    def g(self):
        print("Laptop is of brand :: ",self.brand)
        print("Laptop is having RAM of  :: ",self.ram)

gl=GamingLaptop()
gl.b()
gl.r()
gl.g()
# Out:
# Laptop is of brand ::  DELL
# Laptop is having RAM of  ::  16 GB

# %%
# Mulitilevel
# a=b , b=c , a=c

class Person:
    def p(self):
        self.name=input("Enter Name :: ")

class Employee(Person):
    def e(self):
        self.id=int(input("Enter ID :: "))

class Manager(Employee):
    def m(self):
        print(self.name,self.id)

m=Manager()
m.p()
m.e()
m.m()
# Out:
# Ram 101

# %%
class Animal:
    def an(self):
        self.type=input("Enter type of animal :: ")

class Cat(Animal):
    def cat(self):
        self.breed=input("Enter Breed :: ")

class Kitten(Cat):
    def kit(self):
        print("Kitten is of type : ",self.type ," and of breed ",self.breed)

k=Kitten()
k.an()
k.cat()
k.kit()
# Out:
# Kitten is of type :  Cat  and of breed  Persian

# %%
class Bank:
    def b(self):
        self.name=input("Enter Bank Name :: ")

class Account(Bank):
    def a(self):
        self.acc=int(input("Enter Account Number :: "))

class Savings(Account):
    def sa(self):
        print("Bank name is :: ",self.name)
        print("Account No  :: ",self.acc)
        print("Saving Account has 6 % of Interest ")


s=Savings()
s.b()
s.a()
s.sa()
# Out:
# Bank name is ::  sbi
# Account No  ::  345678
# Saving Account has 6 % of Interest

# %%
# Hierachical 

class Vehicle:
    def v(self):
        self.brand=input("Enter Brand name :: ")

class Car(Vehicle):
    def c(self):
        print("Car is :: ",self.brand)

class Bike(Vehicle):
    def b(self):
        print("Bike Is :: ",self.brand)

class SportsBike(Bike):
      def sb(self):
        print("Sport Bike Is :: ",self.brand)

c=Car()
c.v()
c.c()

b=Bike()
b.v()
b.b()

sb=SportsBike()
sb.v()
sb.sb()
# Out:
# Car is ::  SUZUKI
# Bike Is ::  TVS
# Sport Bike Is ::  R15

# %%
class Employee:
    def emp(self):
        self.name=input("Enter Name :: ")

class Developer(Employee):
    def dev(self):
        print(self.name , "is a Developer ")

class Tester(Employee):
    def test(self):
        print(self.name," is a tester ")

class SQLManager(Employee):
    def sql(self):
        print(self.name, " is a SQL Manager ")


d=Developer()
d.emp()
d.dev()

t=Tester()
t.emp()
t.test()

s=SQLManager()
s.emp()
s.sql()
# Out:
# Ram is a Developer
# Raj  is a tester
# Ajay  is a SQL Manager

# %%
class Shape:
    def sh(self):
        self.sides=int(input("Enter Sides :: "))
    
class Rectangle(Shape):
    def rect(self):
        print("Rectangle is of  side :: ",self.sides)

    
class Triangle(Shape):
    def tri(self):
        print("Triangle is of  side :: ",self.sides)

    
class Circle(Shape):
    def cir(self):
        print("Circle is of  side :: ",self.sides)

    
class Pentagon(Shape):
    def pen(self):
        print("Pentagon is of  side :: ",self.sides)

r=Rectangle()
r.sh()
r.rect()


t=Triangle()
t.sh()
t.tri()

c=Circle()
c.sh()
c.cir()

p=Pentagon()
p.sh()
p.pen()
# Out:
# Rectangle is of  side ::  4
# Triangle is of  side ::  3
# Circle is of  side ::  0
# Pentagon is of  side ::  5

# %%
import math

class Shape:
    def sh(self):
        self.sides = int(input("Enter number of sides: "))


class Rectangle(Shape):
    def rect(self):
        self.length = float(input("Enter length: "))
        self.breadth = float(input("Enter breadth: "))
        area = self.length * self.breadth
        print("Rectangle area =", area)


class Triangle(Shape):
    def tri(self):
        self.base = float(input("Enter base: "))
        self.height = float(input("Enter height: "))
        area = 0.5 * self.base * self.height
        print("Triangle area =", area)


class Circle(Shape):
    def cir(self):
        self.radius = float(input("Enter radius: "))
        area = math.pi * self.radius * self.radius
        # area = 3.14 * self.radius * self.radius
        print("Circle area =", area)


class Pentagon(Shape):
    def pen(self):
        self.side = float(input("Enter side length: "))
        area = (5 * self.side * self.side) / (4 * math.tan(math.pi/5))
        print("Pentagon area =", area)


# Objects
r = Rectangle()
r.sh()
r.rect()

t = Triangle()
t.sh()
t.tri()

c = Circle()
c.sh()
c.cir()

p = Pentagon()
p.sh()
p.pen()
# Out:
# Rectangle area = 6.0
# Triangle area = 3.0
# Circle area = 12.566370614359172
# Pentagon area = 15.484296605300704

# %%
# Hybrid 

class Person:
    def p(self):
        self.name=input("Enter Name :: ")

class Employee(Person):
    def e(self):
        self.id=input("Enter ID :: ")
    
class Student(Person):
    def s(self):
        self.course=input("Course :: ")

class Intern(Employee,Student):
    def stud(self):
        print(self.name,self.id,self.course)

obj=Intern()
obj.p()
obj.e()
obj.s()
obj.stud()
# Out:
# Ram 101 Python

# %%
class Company:
    def c(self):
        self.name=input("Enter Company Name :: ")

class HR(Company):
    def hr(self):
        self.hires=input("Hires :: ")
    
class Tech(Company):
    def tech(self):
        self.tech=input("Tech :: ")

class Manager(HR,Tech):
    def man(self):
        print("Company Name :: ",self.name)
        print("Hiring Count is  :: ",self.hires)
        print("Technology Name :: ",self.tech)

obj=Manager()
obj.c()
obj.hr()
obj.tech()
obj.man()
# Out:
# Company Name ::  Tata
# Hiring Count is  ::  20
# Technology Name ::  Python

# %% [markdown]
# # **`super()` Function in Python**
#
# ## **Definition**
#
# The `super()` function is used to **call the methods or constructor (`__init__`) of the parent class** from the child class.
#
# It helps avoid rewriting code and allows the child class to reuse the functionality of the parent class.
#
# ---
#
# # **Advantages of `super()`**
#
# * Reuses the parent class code.
# * Reduces code duplication.
# * Makes programs easier to maintain.
# * Allows the child class to extend the functionality of the parent class.
#
# ---
#
# # **Syntax**
#
# ```python
# super().method_name()
# ```
#
# or
#
# ```python
# super().__init__()
# ```
#
# ---
#
# # **Example 1: Calling Parent Class Method**
#
# ```python
# class Person:
#
#     def display(self):
#         print("I am Person")
#
# class Student(Person):
#
#     def show(self):
#         super().display()
#         print("I am Student")
#
# s = Student()
# s.show()
# ```
#
# ### **Output**
#
# ```
# I am Person
# I am Student
# ```
#
# ### **Explanation**
#
# * `Student` inherits `Person`.
# * `super().display()` calls the `display()` method of the parent class.
# * Then the child class prints `"I am Student"`.
#
# ---
#
# # **Example 2: Using `super()` with Constructor**
#
# ```python
# class Person:
#
#     def __init__(self):
#         self.name = input("Enter Name: ")
#
# class Student(Person):
#
#     def __init__(self):
#         super().__init__()
#         self.roll = int(input("Enter Roll Number: "))
#
#     def display(self):
#         print("Name:", self.name)
#         print("Roll Number:", self.roll)
#
# s = Student()
# s.display()
# ```
#
# ### **Sample Output**
#
# ```
# Enter Name: Rahul
# Enter Roll Number: 101
# Name: Rahul
# Roll Number: 101
# ```
#
# ### **Explanation**
#
# * `super().__init__()` calls the parent class constructor.
# * The parent constructor accepts the student's name.
# * The child constructor accepts the roll number.
# * Both values are displayed using the child class method.
#
# ---
#
# # **Example 3: Parent Constructor with Parameters**
#
# ```python
# class Employee:
#
#     def __init__(self, name):
#         self.name = name
#
# class Manager(Employee):
#
#     def __init__(self, name, salary):
#         super().__init__(name)
#         self.salary = salary
#
#     def display(self):
#         print("Name:", self.name)
#         print("Salary:", self.salary)
#
# m = Manager("Amit", 50000)
# m.display()
# ```
#
# ### **Output**
#
# ```
# Name: Amit
# Salary: 50000
# ```
#
# ---
#
# # **Exam Theory (2 Marks)**
#
# **Q. What is `super()` in Python?**
#
# **Answer:**
#
# The `super()` function is used to access the methods and constructor of the parent class from the child class. It helps in code reusability and avoids rewriting the parent class code.
#
# **Example:**
#
# ```python
# class A:
#     def display(self):
#         print("Class A")
#
# class B(A):
#     def show(self):
#         super().display()
#         print("Class B")
#
# obj = B()
# obj.show()
# ```
#
# **Output**
#
# ```
# Class A
# Class B
# ```
#
# ---
#
# ## **Interview Question**
#
# ### **Q. Why do we use `super()` instead of directly calling the parent class?**
#
# **Answer:**
#
# * `super()` automatically refers to the parent class, making the code easier to maintain.
# * If the parent class name changes, you do not need to update every method call.
# * It is especially useful in **multiple inheritance**, where Python follows the **Method Resolution Order (MRO)** to determine which parent method to call.
