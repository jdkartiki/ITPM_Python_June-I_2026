# %% [markdown]
# ### RULES FOR CONSTRUCTOR
# * __init__() -- create the constructor
# * will not have any return type
# * it is not necessary to call the constructor
# * once the object is created automatically the constructor is called

# %% [markdown]
# Dunder Methods in Python (Magic Methods)
#
# **Dunder = “Double UNDERscore” methods**
# They are special methods with names like:
#
# ```python
# __init__, __str__, __len__, __add__
# ```
#
# Called **automatically by Python** to perform built-in operations.
#
# ---
#
# What are Dunder Methods?
#
# Special methods that let you **define how your objects behave**
#
# Example:
#
# ```python
# print(obj)     → calls obj.__str__()
# len(obj)       → calls obj.__len__()
# a + b          → calls a.__add__(b)
# ```
#
# ---
#
# Common Dunder Methods
#
# | Method     | Use                               |
# | ---------- | --------------------------------- |
# | `__init__` | Constructor (initialize object)   |
# | `__str__`  | String representation (for print) |
# | `__repr__` | Developer representation          |
# | `__len__`  | Length using `len()`              |
# | `__add__`  | `+` operator                      |
# | `__sub__`  | `-` operator                      |
# | `__eq__`   | `==` comparison                   |
#
# ---
#
# Example 1: `__init__` (Constructor)
#
# ```python
# class Student:
#     def __init__(self, name):
#         self.name = name
#
# s = Student("Kartiki")
# print(s.name)
# ```
#
# Runs automatically when object is created
#
# ---
#
# Example 2: `__str__`
#
# ```python
# class Student:
#     def __init__(self, name):
#         self.name = name
#
#     def __str__(self):
#         return f"Student name is {self.name}"
#
# s = Student("Kartiki")
# print(s)
# ```
#
# Output:
#
# ```
# Student name is Kartiki
# ```
#
# ---
#
# Example 3: `__len__`
#
# ```python
# class MyList:
#     def __init__(self, items):
#         self.items = items
#
#     def __len__(self):
#         return len(self.items)
#
# obj = MyList([1, 2, 3, 4])
# print(len(obj))   # Output: 4
# ```
#
# ---
#
# Example 4: `__add__`
#
# ```python
# class Number:
#     def __init__(self, value):
#         self.value = value
#
#     def __add__(self, other):
#         return self.value + other.value
#
# a = Number(10)
# b = Number(20)
#
# print(a + b)   # Output: 30
# ```
#
# ---
#
# Why Use Dunder Methods?
#
# * Make objects behave like **built-in types**
# * Enable **operator overloading**
# * Improve **readability & usability**
#
# ---
#
# Real-Life Meaning
#
# * `__init__` → “When object is created, do this”
# * `__str__` → “How to display object”
# * `__add__` → “What happens when we use +”
#
# ---
#
# * Important Note
#
# 👉 Don’t call them directly:
#
# ```python
# obj.__str__()   ❌ (avoid)
# print(obj)      ✅ (correct)
# ```
#
# ---
#
# Easy Way to Remember
#
# 👉 Dunder methods = **hidden magic behind Python operations**

# %%
# prove that constructor is called automatically

class Demo:
    def __init__(self):
        print("Constructor is Called !!!!!")
    
#  created object using variable 
# d=Demo()

# creating object at runtime
Demo()
# Out:
# Constructor is Called !!!!!

# %%
# Parametrized COnstructor

class Student:
    def __init__(self,rollno,name,courrse):
        self.rollno=rollno
        self.name=name
        self.course=courrse


s1=Student(1,"Ram","Python")
s2=Student(2,"Raj","AI/ML")

print(s1.rollno, s1.name, s1.course)
print(s2.rollno,s2.name,s2.course)
# Out:
# 1 Ram Python
# 2 Raj AI/ML

# %%
class Student:
    def __init__(self,name,course):
        self.name=name
        self.course=course

    def display(self):
        print("======== Student Details ==========")
        print("NAme is :: ",self.name)
        print("Course is :: ",self.course)


#user input
n1=input("Enter Name :: ")
c1=input("Enter COurse Name :: ")
s1=Student(n1,c1)
s1.display()

n2=input("Enter Name :: ")
c2=input("Enter COurse Name :: ")
s2=Student(n2,c2)
s2.display()
# Out:
# ======== Student Details ==========
# NAme is ::  RAM
# Course is ::  PYTHON
# ======== Student Details ==========
# NAme is ::  PRIYA
# Course is ::  DATA SCIENCE

# %%
class Bank:
    def __init__(self,name,balance):
        self.name=name
        self.balance=balance

    def deposit(self,damt):
        self.balance+=damt
        print("Deposited AMount is :: ",damt)
        print("Balance AMount is :: ",self.balance)

    def withdraw(self,wamt):
        self.balance-=wamt
        print("Withdraw AMount is :: ",wamt)
        print("Balance AMount is :: ",self.balance)


name=input("Enter Account Holder Name :: ")
balance=float(input("Enter Balance :: "))

acc=Bank(name,balance)

damt=float(input("Enter Deposit AMount :: "))
acc.deposit(damt)

wamt=float(input("Enter Withdraw AMount :: "))
acc.withdraw(wamt)
# Out:
# Deposited AMount is ::  5000.0
# Balance AMount is ::  15000.0
# Withdraw AMount is ::  2000.0
# Balance AMount is ::  13000.0

# %%
# Product Details 
class Product:
    def __init__(self,name,price,quantity):
        self.name=name
        self.price=price
        self.quantity=quantity


    def total(self):
        return self.price*self.quantity
    

name=input("Enter Name :: ")
price=float(input("Enter Price :: "))
quantity=int(input("enter Quantity :: "))

p=Product(name,price,quantity)
print("Product Name is :: ",p.name)
print("Price for Each Product is :: ",p.price)
print("Total Cost is :: ",p.total())
# Out:
# Product Name is ::  Shoes
# Price for Each Product is ::  1000.0
# Total Cost is ::  5000.0

# %%
# car rental 
# car name 
# rentperday
# days
# total rent for all days
