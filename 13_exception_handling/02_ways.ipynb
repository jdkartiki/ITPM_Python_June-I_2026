# %%
# multiple Except block 
try:
    a=int(input("Enter number :: "))
    b=a/0
except ZeroDivisionError:
    print("Cannot divide by Zero ")
except ValueError:
    print("Invalid Input ")
# Out:
# Invalid Input

# %%
# else block will be always be executed when there is no exception 

try:
    num=int(input("Enter Number :: "))
except ValueError:
    print("Error !!! Give a Valid Input ")
else:
    print("Value of num is :: ",num)
# Out:
# Value of num is ::  88

# %%
# finally run when there is exception or not 

try:
    f=open("file.txt","r")
except FileNotFoundError:
    print("Errorr")
finally:
    print("Exceution Completed and file is closed")
# Out:
# Errorr
# Exceution Completed and file is closed

# %%
# raise -- raise 
age=int(input("Enter Age :: "))

if age<18:
    raise Exception("Not Eligible For Driving!!!")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 age=int(input("Enter Age :: "))
#       4 if age<18:
# ----> 5     raise Exception("Not ELogible For Driving!!!")
#
# Exception: Not ELogible For Driving!!!
