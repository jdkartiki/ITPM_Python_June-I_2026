# %% [markdown]
# Exception Handling in Python
#
# ---
#
# ## 🔹 1. What is Exception Handling?
#
# Exception Handling is a mechanism to handle runtime errors so that the program does not crash and continues execution smoothly.
#
# 👉 **Example error:**
#
# ```python
# a = 10 / 0   # ZeroDivisionError
# ```
#
# * Without handling → program stops ❌
# * With handling → program continues ✅
#
# ---
#
# ## 🔹 2. Types of Errors
#
# ### 1. Syntax Errors
#
# Occur due to incorrect syntax
#
# ```python
# if x == 10   # missing colon
# ```
#
# ---
#
# ### 2. Runtime Errors (Exceptions)
#
# Occur during execution
#
# ```python
# int("abc")   # ValueError
# ```
#
# ---
#
# ## 🔹 3. Common Built-in Exceptions
#
# * `ZeroDivisionError`
# * `ValueError`
# * `TypeError`
# * `IndexError`
# * `KeyError`
# * `FileNotFoundError`
#
# ---
#
# ## 🔹 4. Try-Except Block
#
# ```python
# try:
#     x = int(input("Enter number: "))
#     print(10 / x)
# except:
#     print("Error occurred")
# ```
#
# ---
#
# ## 🔹 5. Multiple Except Blocks
#
# ```python
# try:
#     a = int(input("Enter number: "))
#     b = 10 / a
# except ZeroDivisionError:
#     print("Cannot divide by zero")
# except ValueError:
#     print("Invalid input")
# ```
#
# ---
#
# ## 🔹 6. Else Block
#
# 👉 Runs only if no exception occurs.
#
# ```python
# try:
#     x = int(input("Enter number: "))
# except ValueError:
#     print("Error")
# else:
#     print("You entered:", x)
# ```
#
# ---
#
# ## 🔹 7. Finally Block
#
# 👉 Always executes (important for cleanup)
#
# **Notes:**
#
# 1. Used for closing file connections
# 2. Used for closing database connections (whether error occurs or not)
#
# ```python
# try:
#     f = open("file.txt")
# except:
#     print("Error")
# finally:
#     print("Execution completed")
# ```
#
# ---
#
# ## 🔹 8. Raising Exceptions
#
# What is raise in Python?
#
# The raise keyword is used to manually generate (throw) an exception in Python. It allows the programmer to stop the normal execution of a program and display an error message when a specific condition occurs.
#
# It is commonly used for:
#
# * Input validation
# * Preventing invalid operations
# * Creating custom error messages
# * Raising custom exceptions
#
# Why do we use raise?
# The raise keyword is used to:
# * Validate user input
# * Prevent invalid data from being processed
# * Make debugging easier
# * Inform users about incorrect operations
# * Stop program execution when necessary
#
# Advantages of raise
# * Improves program reliability.
# * Validates user input effectively.
# * Makes debugging easier.
# * Prevents invalid operations.
# * Supports custom exception handling.
# * Produces meaningful error messages.
#
# Difference Between raise and try...except
#         raise	                            |    try...except
# Generates an exception manually.	        |    Handles an exception.
# Stops program execution unless handled.	    |    Prevents the program from crashing.
# Used to report an error.	                |    Used to recover from an error.
# Used when a condition is invalid.	        |    Used when an exception may occur.
#
#
# Key Points to Remember
# * raise is used to manually generate an exception.
# * It can raise both built-in and custom exceptions.
#
# ```python
# age = int(input("Enter age: "))
#
# if age < 18:
#     raise Exception("Not eligible")
# ```
#
# ---
#
# ## 🔹 9. User-Defined Exceptions
#
# 👉 We create custom exceptions using a class.
#
# ```python
# class MyError(Exception):
#     pass
#
# try:
#     raise MyError("Custom error occurred")
# except MyError as e:
#     print(e)

# %%
# inbuilt exception

# ZeroDivisionError 
try:
    a=int(input("Enter number one  :: "))
    b=int(input("Enter number two  :: "))
    print(a/b)
except ZeroDivisionError:
    print("Cannot Divide the number by zero ")
# Out:
# Cannot Divide the number by zero

# %%
# Value Error
try:
    num=int(input("enter Numebr :: "))
except ValueError:
    print("Invalid Input is not Allowed ! Please Enter Number only")
# Out:
# Invalid Input is not Allowed ! Please Enter Number only

# %%
# type Error

try:
    num="10"+5
except TypeError:
    print("Cannot Concat String and number ")
# Out:
# Cannot Concat String and number

# %%
# index Error
try:
    lst=[10,20,30]
    print(lst[8])
except IndexError:
    print("Index Out Of Range / Bound")
# Out:
# Index Out Of Range / Bound

# %%
# key Error

try:
    d={"name":"Kartiki"}
    print(d["designation"])
except KeyError:
    print("Key Not FOund")
# Out:
# Key Not FOund

# %%
# File NOt Found

try:
    f=open("abc.txt")
except FileNotFoundError:
    print("File Doesnot Not Exists ")
# Out:
# File Doesnot Not Exists

# %%
# Attribute Error

try:
    num=10
    num.append(5)
except AttributeError:
    print("Attribute not FOund")
# Out:
# Attribute not FOund

# %%
# import error
try:
    import xyz
except ImportError:
    print("Module Not Found ")
# Out:
# Module Not Found

# %%
# name error
try:
    print(m)
except NameError:
    print("Variable NOt Declared")
# Out:
# Variable NOt Declared

# %%
# Module Error 
try:
    import xyz
except ModuleNotFoundError:
    print("Module NOt Found")

# %%
# IOError
try:
    f=open("/C/path/a.txt","r")
except IOError:
    print("Input/OutPut Error !!! ")
# Out:
# Input/OutPut Error !!!

# %%
#overflow error

import math

try:
    num=int(input("Enter number :: "))
    print(math.exp(num))
except OverflowError:
    print("Number too large")
# Out:
# Number too large

# %%
# Assert 
#Assertion -- it is a debugging tool used to check the conditiion
# if condition is true nothing changes , but if false exception will be raised 

try:
    num=int(input("Enter Number > 0:: "))
    assert num>0
    print("Valid Number ")
except AssertionError:
    print("Number must be greater than 0 ")
# Out:
# Number must be greater than 0

# %%
try:
    age=int(input("Enter Age > 18 :: "))
    assert age>=18
    print("Can Vote !!!")
except AssertionError:
    print("Age should be >=18 to VOte !!!")
# Out:
# Age should be >=18 to VOte !!!

# %%
# Stop Iteration 
try:
    lst=[10,20,30,40]
    itr=iter(lst)
    print(next(itr))
    print(next(itr))
    print(next(itr))
    print(next(itr))
    print(next(itr))
    print(next(itr))
except StopIteration:
    print("No More Elements to Print !!!")
# Out:
# 10
# 20
# 30
# 40
# No More Elements to Print !!!

# %%
# keyboard interrupt
try:
    while True:
        num=input("Enter or Ctrl+c to STop ")
except KeyboardInterrupt:
    print("Program terminatted by UseR!!!")
# Out:
# Program terminatted by UseR!!!
