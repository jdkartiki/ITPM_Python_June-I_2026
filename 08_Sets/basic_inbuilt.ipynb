# %% [markdown]
# #  Python Sets - Complete Notes
#
# ## 1. What is a Set?
#
# A **set** in Python is a collection of **unordered and unique elements** enclosed in curly braces `{ }`.
#
# * Sets do not allow duplicate values
# * Sets are **mutable** (can be changed)
# * Elements must be **immutable** (e.g., numbers, strings, tuples)
#
# ### Example
#
# ```python id="s1a2b3"
# numbers = {10, 20, 30, 40}
# mixed = {1, "Python", 3.5, True}
# ```
#
# ---
#
# ## 2. Characteristics of Sets
#
# * ❌ Unordered (no fixed position/index)
# * ✔ Mutable (can add/remove elements)
# * ❌ No duplicate values
# * ❌ No indexing & slicing
# * ✔ Fast membership testing
#
# ---
#
# ## 3. Creating Sets
#
# ### Empty Set (Important)
#
# ```python id="s3d4f5"
# eg:
# 1. lst=[]
# 2. tuple=()
# 3. s={} not allowed since it will craete empty dictonary
# s = set()   # NOT {}
# ```
#
# ### Using Curly Braces
#
# ```python id="s6g7h8"
# s = {1, 2, 3, 4}
# ```
#
# ### From List
#
# ```python id="s9i0j1"
# s = set([1, 2, 2, 3])
# print(s)   # {1, 2, 3}
# ```
#
# ### Nested Set (Using frozenset)
#
# ```python id="s2k3l4"
# a = frozenset([1, 2])
# b = frozenset([3, 4])
# s = {a, b}
# ```
#
# ---
#
# ## 4. Set Operations (Mathematical)
#
# ```python id="s5m6n7"
# a = {1, 2, 3}
# b = {3, 4, 5}
# ```
#
# ### Union
#
# ```python id="s8o9p0"
# print(a | b)        # {1, 2, 3, 4, 5}
# print(a.union(b))
# ```
#
# ### Intersection
#
# ```python id="s1q2r3"
# print(a & b)        # {3}
# print(a.intersection(b))
# ```
#
# ### Difference
#
# ```python id="s4t5u6"
# print(a - b)        # {1, 2}
# print(a.difference(b))
# ```
#
# ### Symmetric Difference
#
# ```python id="s7v8w9"
# print(a ^ b)        # {1, 2, 4, 5}
# print(a.symmetric_difference(b))
# ```
#
# ---
#
# ## 5. Adding & Removing Elements
#
# ### Add Elements
#
# ```python id="s0x1y2"
# s = {1, 2}
# s.add(3)
# ```
#
# ### Add Multiple Elements
#
# ```python id="s3z4a5"
# s.update([4, 5])
# ```
#
# ### Remove Elements
#
# ```python id="s6b7c8"
# s.remove(2)   # Error if not found
# s.discard(10) # No error
# s.pop()       # Removes random element
# ```
#
# ### Clear Set
#
# ```python id="s9d0e1"
# s.clear()
# ```
#
# ---
#
# ## 6. Traversing Sets
#
# ```python id="s2f3g4"
# s = {10, 20, 30}
#
# for i in s:
#     print(i)
# ```
#
# *(Note: Order may vary)*
#
# ---
#
# ## 7. Set Methods
#
# | Method                 | Description                      |
# | ---------------------- | -------------------------------- |
# | add()                  | Add element                      |
# | update()               | Add multiple elements            |
# | remove()               | Remove element (error if absent) |
# | discard()              | Remove element (no error)        |
# | pop()                  | Remove random element            |
# | clear()                | Remove all elements              |
# | union()                | Combine sets                     |
# | intersection()         | Common elements                  |
# | difference()           | Elements in first only           |
# | symmetric_difference() | Non-common elements              |
# | issubset()             | Check subset                     |
# | issuperset()           | Check superset                   |
#
# ---
#
# ## 8. Set Operators
#
# ```python id="s5h6i7"
# a = {1, 2}
# b = {2, 3}
# ```
#
# * Union → `a | b`
# * Intersection → `a & b`
# * Difference → `a - b`
# * Symmetric Difference → `a ^ b`
#
# ---
#
# ## 9. Membership Testing
#
# ```python id="s8j9k0"
# s = {10, 20, 30}
# print(20 in s)   # True
# print(50 in s)   # False
# ```
#
# ---
#
# ## 10. Frozen Set
#
# A **frozenset** is an immutable version of a set.
#
# ```python id="s1l2m3"
# fs = frozenset([1, 2, 3])
# ```
#
# * Cannot add/remove elements
# * Can be used as dictionary keys
#
# ---
#
# ## 11. Copying Sets
#
# ### Shallow Copy
#
# ```python id="s4n5o6"
# a = {1, 2, 3}
# b = a.copy()
# ```
#
# ### Reference Copy
#
# ```python id="s7p8q9"
# b = a
# ```
#
# ---
#
# ## 12. Important Set Programs (Exam)
#
# ### Remove Duplicates from List
#
# ```python id="s0r1s2"
# lst = [1, 2, 2, 3]
# unique = list(set(lst))
# print(unique)
# ```
#
# ### Find Common Elements
#
# ```python id="s3t4u5"
# a = {1, 2, 3}
# b = {2, 3, 4}
# print(a & b)
# ```
#
# ### Check Subset
#
# ```python id="s6v7w8"
# a = {1, 2}
# b = {1, 2, 3}
# print(a.issubset(b))
# ```
#
# ---
#
# ## 13. Real-Life Applications of Sets
#
# * 🎯 Removing duplicates from data
# * 🔍 Fast searching & membership testing
# * 📊 Mathematical operations (union, intersection)
# * 🧠 Data analysis & filtering
#
# ---

# %%
# define set and print
s={10,20,30}
print(s)
print(type(s))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
# creating empty set 
# note :: don't use {} brace for creating set since by default {} brace is determined to have the empty dict not set 

student = set()
print(type(student))
# Out:
# <class 'set'>

# %%
s={10,20,30,40}

#single element add
s.add(50)
print(s)

#multiple elements add
s.update([50,60,70,80])
print(s)
# Out:
# {40, 10, 50, 20, 30}
# {70, 40, 10, 80, 50, 20, 60, 30}

# %%
s={10,20,30,40,50,60,70}

# remove element , but if not found --error
s.remove(30)
print(s)

# s.remove(100)
# print(s)
# will give error of element is not found 

s.discard(100) # remove safely
print(s)
# no error it will return empty value if not matched 

s.pop() # first element of displayed set  will be removed 
print(s)  

s.clear() # it will empty your set 
print(s)
# Out:
# {50, 20, 70, 40, 10, 60}
# {50, 20, 70, 40, 10, 60}
# {20, 70, 40, 10, 60}
# set()

# %%
# membership test in set 
my_set={1,2,3,4,5}
print(3 in my_set)
print(10 in my_set)

# checks whether the element is present ot not  : true or false
# Out:
# True
# False

# %%
# simple function
s={10,20,30,40,50,60,70}

print(len(s))
print(min(s))
print(max(s))
print(sum(s))
# Out:
# 7
# 10
# 70
# 280

# %%
# remove the duplicates from list 
lst=[10,20,30,30,30,30]
res=list(set(lst))
print(res)
# Out:
# [10, 20, 30]

# %%
s1={10,20,30}
s2={30,40,50}

union_set=s1.union(s2)
print(union_set)
#union
print(s1.union(s2))
# Out:
# {50, 20, 40, 10, 30}
# {50, 20, 40, 10, 30}

# %% [markdown]
# I. intersection()
#
#  1. Returns a new set with common elements
#  2. Does NOT modify original sets
#
#
# II. intersection_update()
#
#  1. Updates the original set itself
#  2. Keeps only common elements
#
#
# Imp : When to Use What?
# 1. Use intersection() -- when you want to keep original sets safe
# 2. Use intersection_update() --  when you want to directly modify the set for efficiency

# %%
s1={10,20,30,40,50}
s2={40,50,60,70}

#intersection will only give you common element
print(s1.intersection(s2))
print(s1)
print(s2)

# intersection update will find common element and add that element in s1 
s1.intersection_update(s2)
print(s1)
# Out:
# {40, 50}
# {50, 20, 40, 10, 30}
# {40, 50, 60, 70}
# {40, 50}

# %% [markdown]
# I. difference()
#
# Returns elements that are in set A but NOT in set B
#
# Meaning:
# Remove common elements
# Keep only elements unique to first set
#
#
# II. symmetric_difference()
#
# Returns elements that are in either set, but NOT in both
#
# Meaning:
# Remove common elements
# Keep elements from both sets except common ones
#
# Quick Understanding
# 1. difference()
# “What is in A but not in B?”
# 2. symmetric_difference()
# “What is different between A and B?”

# %%
s1={10,20,30}
s2={20,30,40,50}

#difference
print(s2.difference(s1))
print(s1.difference(s2))
# Out:
# {40, 50}
# {10}

# %%
a={1,2,3}
b={2,3,4}

#symmetric difference
print(a.symmetric_difference(b))
# Out:
# {1, 4}

# %%
# sub set of any set 

a={1,2}
b={1,2,3}

#subset
print(a.issubset(b))
print(b.issubset(a))
# Out:
# True
# False

# %%
# should contains all elements from subset 

a={1,2}
b={1,2,3}

#superset
print(b.issuperset(a))
# Out:
# True

# %%
# check the common elements

a=[1,2,3,4]
b=[3,4,5,6]

print(set(a).intersection(set(b)))
# Out:
# {3, 4}

# %%
#count unique elements
lst=[1,2,2,3,3,4,4]

print(len(set(lst)))
# Out:
# 4

# %%
#remove dupliactes from string
s="programming"
print(set(s))
# Out:
# {'g', 'r', 'n', 'o', 'i', 'm', 'p', 'a'}

# %%
# remove unique word from string
text="Python is a Programming language Python is a Interpreted language"
words=text.split()

#convert to set for uniqueness sincce it acts as list of words 
unique_words=set(words)
print(unique_words)
print(len(unique_words))
# Out:
# {'Programming', 'Interpreted', 'is', 'a', 'language', 'Python'}
# 6

# %%
# find the missing element

a={1,2,3,5}
b={1,2,3,4,5}

print(b-a)
print(a-b)
# b-a : elements that are there in b but not in a
# Out:
# {4}
# set()

# %%
# Remove common element

a={1,2,3,5,10,20}
b={1,2,3,4,5,6}

print(a.symmetric_difference(b))
# Out:
# {4, 6, 20, 10}

# %%
#disjoint  : compulsary two sets should be different 
a={1,2,3}
b={4,5,6}

print(a.isdisjoint(b))
# Out:
# True

# %%
# find pair with given sum

arr=[1,2,3,4,5]
target=6

seen=set()

for num in arr:
    if target-num in seen:
        print(num,target-num)
    seen.add(num)
# Out:
# 4 2
# 5 1

# %%
# First Non Repeating elements

lst=[1,2,2,3,1,4]

for i in lst:
    if lst.count(i)==1:
        print(i)
        break
# Out:
# 3

# %%
# find duplicate

lst=[1,2,3,2,3,4,5,4,3]

seen=set()

for i in lst:
    if i in seen:
        print("Duplicate Element : ",i)
    else:
        seen.add(i)

print(seen)
# Out:
# Duplicate Element :  2
# Duplicate Element :  3
# Duplicate Element :  4
# Duplicate Element :  3
# {1, 2, 3, 4, 5}
