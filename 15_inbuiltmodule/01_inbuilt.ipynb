# %% [markdown]
# ### PYTHON INBUILT MODULES (Standard Library)
# What are Inbuilt Modules?
#
# Inbuilt modules (also called Standard Library modules) are pre-written Python files that come installed with Python.
#
# 👉 They provide ready-made functions for:
#
# 1. File handling
# 2. Math operations
# 3. Date & time
# 4. OS interaction
# 5. Data processing
# 6. Networking, etc.
#
# 📌 You don’t need to install them — just import and use
#
# 🔹 Why use Inbuilt Modules?
# * Saves development time
# * Reliable & optimized
# * Reduces code complexity
# * Industry standard
#
# 🔹 How to Use Modules?
# * import module_name
#
# or
#
# * from module_name import function_name
#
#
# 🔹 Types of Modules
# * Built-in Modules (Standard Library)
# * User-defined modules
# * External modules (like numpy, pandas)
#
# 📦 List of Important Inbuilt Modules
# * System & OS
# 1. os
# 2. sys
# 3. platform
# 4. shutil
#
# * Math & Numbers
# 1. math
# 2. random
# 3. statistics
# 4. decimal
#
# * Date & Time
# 1. datetime
# 2. time
# 3. calendar
#
# * File & Data Handling
# 1. json
# 2. csv
# 3. pickle
#
# * String & Text Processing
# 1. re
# 2. string
#
# * Data Structures
# 1. collections
# 2. heapq
# 3. bisect
#
# * Utilities
# 1. itertools
# 2. functools
# 3. operator
#
# * Networking & Web
# 1. socket
# 2. http
# 3. urllib
#
# Note :: https://docs.python.org/3/py-modindex.html

# %%
print("hello")
# Out:
# hello

# %%
# Math Module

import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
import math
print(math.factorial(5))
# Out:
# 120

# %%
#random

import random
otp = random.randint(1000, 9999)
print("OTP:", otp)
# Out:
# OTP: 8496

# %%
import random
print(random.choice(["Pizza", "Burger", "Pasta"]))
# Out:
# Burger

# %%
# Date Time 

from datetime import datetime
print(datetime.now())
# Out:
# 2026-09-15 11:06:09.904568

# %%
# interview question 
from datetime import datetime
birth_year = 1989
age = datetime.now().year - birth_year
print("Age:", age)
# Out:
# Age: 37

# %%
# time

import time
print("Start")
time.sleep(2)
print("End after 2 sec")
# Out:
# Start
# End after 2 sec

# %%
# os

import os
print(os.listdir())
# Out:
# ['01_inbuilt.ipynb', 'abc.py', 'data.csv', 'data.json', 'data.pkl']

# %%
import os
os.mkdir("TestFolder")

# %%
# system- sys
import sys
print(sys.argv)
# Out:
# ['d:\\Anaconda\\Lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\Admin\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3a92daf78a33ad32e7d5ba03e61c45f4bb052b737.json']

# %%
# json - write

import json
data = {"name": "Alice", "age": 22}

with open("data.json", "w") as f:
    json.dump(data, f)

# %%
# json - read

import json
with open("data.json", "r") as f:
    data = json.load(f)
    print(data)
# Out:
# {'name': 'Alice', 'age': 22}

# %%
# csv - write
import csv

with open("data.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Name", "Age"])
    writer.writerow(["John", 25])

# %%
#csv read
import csv

with open("data.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['John', '25']

# %%
# re - Email Validation
import re

email = "test@gmail.com"
pattern = r'^[\w\.-]+@[\w\.-]+\.\w+$'
# @ .

if re.match(pattern, email):
    print("Valid Email")
else:
    print("Please give valid email id ")
# Out:
# Valid Email

# %%
# collections - counter 
from collections import Counter

data = ["a", "b", "a", "c", "a"]
print(Counter(data))
# Out:
# Counter({'a': 3, 'b': 1, 'c': 1})

# %%
# collections - default dict 
from collections import defaultdict

# int -- default -- 0
d = defaultdict(int)
# d["a"] initialize to 0
d["a"]+=1
print(d)
# Out:
# defaultdict(<class 'int'>, {'a': 1})

# %%
# itertools - combinations
from itertools import combinations

print(list(combinations([1,2,3], 2)))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
# statistics - mean 

import statistics

data = [10, 20, 30]
print(statistics.mean(data))
# Out:
# 20

# %%
# pickle  - save object

import pickle

data = {"name": "Bob"}

with open("data.pkl", "wb") as f:
    pickle.dump(data, f)
